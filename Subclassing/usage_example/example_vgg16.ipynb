# %% [markdown]
# this jupyter notebook has to be same directory with Subclassing

# %% [markdown]
# ## load dataset

# %%
from Subclassing.datasets import sampled_dataset

sample_data = sampled_dataset.load_data()
print(sample_data.shape)
# Out:
# (5000, 785)

# %%
from Subclassing.utils import dataset_split

data_feature, data_target = dataset_split(sample_data)
print(data_feature.shape, data_target.shape)
# Out:
# (5000, 28, 28, 1) (5000,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data_feature, data_target, test_size=0.2)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.3)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (2800, 28, 28, 1) (2800,)
# (1200, 28, 28, 1) (1200,)
# (1000, 28, 28, 1) (1000,)

# %% [markdown]
# ## load model class

# %%
from keras.layers import Input
from keras import Model
from Subclassing.models import VGG16

num_of_classes = 36

modeel = VGG16(num_of_classes)
input_layer = Input(shape=(28,28,1))
modeel = Model(inputs=[input_layer], outputs=[modeel(input_layer)])
modeel.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  vgg16 (VGG16)               (None, 36)                7947288
#
# =================================================================
# Total params: 7,947,288
# Trainable params: 7,947,288
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-12 06:30:36.156786: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## compile, fit model using callbacks

# %%
modeel.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from Subclassing.utils import F1ScoreCallback
from keras.callbacks import EarlyStopping

epoch_atience = 5

f1callback = F1ScoreCallback(x_val, y_val)
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=epoch_atience,
    verbose=1,
    restore_best_weights=True
)

# %%
model_history = modeel.fit(x_train, y_train, epochs=10, verbose=1, validation_data=(x_val, y_val), callbacks=[
    f1callback,
    earlystop
])
# Out:
# Epoch 1/10
# 38/38 [==============================] - 4s 106ms/step
# 88/88 [==============================] - 47s 532ms/step - loss: 3.3617 - accuracy: 0.1086 - val_loss: 3.2147 - val_accuracy: 0.1200 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 2/10
# 38/38 [==============================] - 2s 61ms/step
# 88/88 [==============================] - 31s 357ms/step - loss: 3.2229 - accuracy: 0.1211 - val_loss: 3.1930 - val_accuracy: 0.1317 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 3/10
# 38/38 [==============================] - 2s 62ms/step
# 88/88 [==============================] - 26s 299ms/step - loss: 3.2201 - accuracy: 0.1293 - val_loss: 3.1945 - val_accuracy: 0.1317 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 4/10
# 38/38 [==============================] - 2s 61ms/step
# 88/88 [==============================] - 26s 298ms/step - loss: 3.2149 - accuracy: 0.1218 - val_loss: 3.1910 - val_accuracy: 0.1317 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 5/10
# 38/38 [==============================] - 2s 61ms/step
# 88/88 [==============================] - 26s 298ms/step - loss: 3.2172 - accuracy: 0.1246 - val_loss: 3.1862 - val_accuracy: 0.1317 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 6/10
# 38/38 [==============================] - 2s 61ms/step
# 88/88 [==============================] - 26s 299ms/step - loss: 3.2145 - accuracy: 0.1293 - val_loss: 3.1865 - val_accuracy: 0.1317 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 7/10
# 38/38 [==============================] - 2s 61ms/step
# 88/88 [==============================] - 26s 298ms/step - loss: 3.2126 - accuracy: 0.1293 - val_loss: 3.1984 - val_accuracy: 0.1317 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 8/10
# 38/38 [==============================] - 2s 61ms/step
# 88/88 [==============================] - 26s 299ms/step - loss: 3.2143 - accuracy: 0.1293 - val_loss: 3.1982 - val_accuracy: 0.1317 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 9/10
# 38/38 [==============================] - 2s 62ms/step
# 88/88 [==============================] - 26s 299ms/step - loss: 3.2146 - accuracy: 0.1293 - val_loss: 3.1866 - val_accuracy: 0.1317 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 10/10
# 38/38 [==============================] - 2s 61ms/step
# Restoring model weights from the end of the best epoch: 5.
# 88/88 [==============================] - 26s 298ms/step - loss: 3.2117 - accuracy: 0.1243 - val_loss: 3.1892 - val_accuracy: 0.1317 - val_f1_micro: 0.0075 - val_f1_none: 4.1356e-04
# Epoch 10: early stopping

# %% [markdown]
# ## plot model train history

# %%
import matplotlib.pyplot as plt

# %%
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'val_f1_micro', 'val_f1_none'])

# %%
plt.plot(model_history.history['loss'], label='loss')
plt.plot(model_history.history['val_loss'], label='val_loss')
plt.title("VGG16 : loss")
plt.legend()
plt.show()

# %%
plt.plot(model_history.history['accuracy'], label='accuracy')
plt.plot(model_history.history['val_accuracy'], label='val_accuracy')
plt.title("VGG16 : accuracy")
plt.legend()
plt.show()

# %%
plt.plot(model_history.history['val_f1_micro'], label='val_f1_micro')
plt.title("VGG16 : val_f1_micro")
plt.legend()
plt.show()

# %%
label = "0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ"

max_epoch = max(model_history.epoch)

plt.bar(list(label), model_history.history['val_f1_none'][max_epoch - 1 - epoch_atience], label='val_f1_none')
plt.title(f"VGG16 : val_f1_none, epoch {max_epoch - epoch_atience}")
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots(int(max(model_history.epoch) / 10) + 1, 10, figsize=(45, 30))

for i, ax in enumerate(axes.flat) : 
    if i > len(model_history.epoch) - 1 : 
        break
    ax.bar(list(label), model_history.history['val_f1_none'][i])
    ax.set_title("VGG16 : val_f1_none epoch: {}    ".format(i + 1), fontsize=22)

plt.tight_layout()
plt.show()
